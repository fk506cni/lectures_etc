# %% [markdown]
# get data from open

# %%
# !wget https://www.mhlw.go.jp/content/12400000/000607901.xlsx
# Out:
# --2024-10-27 16:29:20--  https://www.mhlw.go.jp/content/12400000/000607901.xlsx
# Resolving www.mhlw.go.jp (www.mhlw.go.jp)... 184.26.210.77, 2600:140b:1c00:1492::3194, 2600:140b:1c00:14b3::3194
# Connecting to www.mhlw.go.jp (www.mhlw.go.jp)|184.26.210.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116795 (114K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘000607901.xlsx’
#
# 000607901.xlsx      100%[===================>] 114.06K  --.-KB/s    in 0.02s
#
# 2024-10-27 16:29:20 (4.95 MB/s) - ‘000607901.xlsx’ saved [116795/116795]

# %%
# !wget https://www.mhlw.go.jp/content/12400000/000539674.xlsx
# Out:
# --2024-10-27 16:29:21--  https://www.mhlw.go.jp/content/12400000/000539674.xlsx
# Resolving www.mhlw.go.jp (www.mhlw.go.jp)... 184.26.210.77, 2600:140b:1c00:1492::3194, 2600:140b:1c00:14b3::3194
# Connecting to www.mhlw.go.jp (www.mhlw.go.jp)|184.26.210.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 133985 (131K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘000539674.xlsx’
#
# 000539674.xlsx      100%[===================>] 130.84K  --.-KB/s    in 0.03s
#
# 2024-10-27 16:29:21 (4.82 MB/s) - ‘000539674.xlsx’ saved [133985/133985]

# %%
import pandas as pd

# %%
f = "./000539674.xlsx"

# %%
df_org = pd.read_excel(f, sheet_name="外来")
df_org.head()
# Out:
# 外来
# 外来（加算）
# 入院
# 入院（加算）
#   診療年月：H30年04月～H31年03月　Ｅ 画像診断　外来　※集計結果が10未満の場合は「‐」で表示（10未満の箇所が1箇所の場合は10以上の最小値を全て「‐」で表示）※集計対象期間内に名称や点数・金額等に変更がある場合、集計対象期間当初の情報で表示  \
# 0                                                NaN
# 1                                            分類\nコード
# 2                                                NaN
# 3                                               E000
# 4                                               E001
#
#   Unnamed: 1 Unnamed: 2    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN           NaN        NaN        NaN        NaN
# 1       分類名称  診療行為\nコード          診療行為         点数         総計         01
# 2        NaN        NaN           NaN        NaN        NaN        北海道
# 3       透視診断  170000310          透視診断        110     235410       7066
# 4       写真診断  170000410  単純撮影（イ）の写真診断         85   69614130    3817740
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 43 Unnamed: 44 Unnamed: 45  \
# 0        NaN        NaN        NaN  ...         NaN         NaN         NaN
# 1         02         03         04  ...          38          39          40
# 2        青森県        岩手県        宮城県  ...         愛媛県         高知県         福岡県
# 3       4685       3231       5196  ...        3084        1177       14359
# 4     840265     764836    1394591  ...      796151      412345     3326365
#
#   Unnamed: 46 Unnamed: 47 Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1          41          42          43          44          45          46
# 2         佐賀県         長崎県         熊本県         大分県         宮崎県        鹿児島県
# 3        2115        1890        2006        2275        2304        3492
# 4      551850      814854     1069548      814469      726125      976038
#
#   Unnamed: 52
# 0         NaN
# 1          47
# 2         沖縄県
# 3        2492
# 4      687995
#
# [5 rows x 53 columns]

# %% [markdown]
# process data as we can use as dataframe.

# %%
df = pd.read_excel(f, sheet_name="外来", skiprows=2, dtype="object")
cols1 = df.columns
cols2 = df.loc[0,:]
cols2 = [c if c ==c else "" for c in cols2]
# df.head()
# print(cols1[0:6])
# = ["categ_code", "categ_name", "si_code", "si_name", "point", "totalcount"]
cols1_fix = ["categ_code", "categ_name", "si_code", "si_name", "point", "totalcount"] + list(cols1[6:])
cols1_fix
cols = [c1 + "_" + c2 if c2 != "" else c1 for c1, c2 in zip(cols1_fix, cols2)]
# cols
df.columns = cols
df = df.query("si_code == si_code")\
    .assign(categ_code = lambda df:df.categ_code.ffill(),
            categ_name = lambda df:df.categ_name.ffill())

cols_num_fix = df.columns[5:]
# cols_num_fix
for cf in cols_num_fix:
    # print(cf)
    df[[cf]] = df[[cf]].replace("-", "0").astype(float)
df["si_code"]
# cols_num_fix
# Out:
# 外来
# 外来（加算）
# 入院
# 入院（加算）
# 1      170000310
# 2      170000410
# 3      170000510
# 4      170000610
# 5      170000730
#          ...
# 135    170020110
# 136    170033510
# 137    170035010
# 138    170015410
# 139    170019950
# Name: si_code, Length: 139, dtype: object

# %% [markdown]
# define the function the process above

# %%
def f2df_47(f, sheet_name):
    df = pd.read_excel(f, sheet_name=sheet_name, skiprows=2, dtype="object")
    cols1 = df.columns
    cols2 = df.loc[0,:]
    cols2 = [c if c ==c else "" for c in cols2]
    
    # df.head()
    # print(cols1[0:6])
    # = ["categ_code", "categ_name", "si_code", "si_name", "point", "totalcount"]
    cols1_fix = ["categ_code", "categ_name", "si_code", "si_name", "point", "totalcount"] + list(cols1[6:])
    cols1_fix
    cols = [c1 + "_" + c2 if c2 != "" else c1 for c1, c2 in zip(cols1_fix, cols2)]
    # cols
    df.columns = cols
    df = df.query("si_code == si_code")\
        .assign(categ_code = lambda df:df.categ_code.ffill(),
                categ_name = lambda df:df.categ_name.ffill())

    cols_num_fix = df.columns[5:]
    # cols_num_fix
    for cf in cols_num_fix:
        # print(cf)
        df[[cf]] = df[[cf]].replace("-", "0").astype(float)
    return df

# %%
df_47 = f2df_47(f=f, sheet_name="外来")
# Out:
# 外来
# 外来（加算）
# 入院
# 入院（加算）

# %%
df_47.head()
# Out:
#   categ_code categ_name    si_code             si_name point  totalcount  \
# 1       E000       透視診断  170000310                透視診断   110    235410.0
# 2       E001       写真診断  170000410        単純撮影（イ）の写真診断    85  69614130.0
# 3       E001       写真診断  170000510        単純撮影（ロ）の写真診断    43  30452100.0
# 4       E001       写真診断  170000610           特殊撮影の写真診断    96     36956.0
# 5       E001       写真診断  170000730  特殊撮影の写真診断（他方と同時併施）    48     79202.0
#
#       01_北海道    02_青森県    03_岩手県     04_宮城県  ...    38_愛媛県    39_高知県  \
# 1     7066.0    4685.0    3231.0     5196.0  ...    3084.0    1177.0
# 2  3817740.0  840265.0  764836.0  1394591.0  ...  796151.0  412345.0
# 3  1309236.0  281484.0  245393.0   497498.0  ...  366148.0  181094.0
# 4     6306.0     246.0     213.0      120.0  ...     464.0      79.0
# 5     3444.0     823.0     883.0      921.0  ...     579.0     429.0
#
#       40_福岡県    41_佐賀県    42_長崎県     43_熊本県    44_大分県    45_宮崎県   46_鹿児島県  \
# 1    14359.0    2115.0    1890.0     2006.0    2275.0    2304.0    3492.0
# 2  3326365.0  551850.0  814854.0  1069548.0  814469.0  726125.0  976038.0
# 3  1406979.0  213865.0  338842.0   452073.0  278315.0  279615.0  381838.0
# 4     1263.0     587.0     355.0       52.0     312.0      91.0     150.0
# 5     4684.0    1432.0     590.0      343.0     499.0     293.0     596.0
#
#      47_沖縄県
# 1    2492.0
# 2  687995.0
# 3  328381.0
# 4      84.0
# 5     214.0
#
# [5 rows x 53 columns]

# %%
# f_age = "./000607901.xlsx"
# df_age = f2df_47(f_age, sheet_name="外来")

# %% [markdown]
# how about age table?

# %%
f_age = "./000607901.xlsx"
df = pd.read_excel(f_age, sheet_name="外来", skiprows=2, dtype="object")
cols1 = df.columns
cols2 = df.loc[0,:]
cols2 = [c if c ==c else "" for c in cols2]

# print(cols)
# df.head()
# print(cols1[0:6])
# = ["categ_code", "categ_name", "si_code", "si_name", "point", "totalcount"]
cols1_fix = ["categ_code", "categ_name", "si_code", "si_name", "point", "totalcount"] + list(cols1[6:])
# cols1_fix = [c if "Unnamed:" not in c else "" for c in cols1_fix]
d_gen = {
    "男":"male",
    0:"male",
    "女":"female",
    1:"female",
}
cols1_fix2 = []
for i, c in enumerate(cols1_fix):
    if "Unnamed:" in c and i <= 24:
        cols1_fix2.append("male")
    elif "Unnamed:" in c and 25 <= i:
        cols1_fix2.append("female")
    elif c == "男":
        cols1_fix2.append("male")
    elif c == "女":
        cols1_fix2.append("female")
    else:
        cols1_fix2.append(c)
        
# print(cols1_fix2)
# cols1_fix = [c if "Unnamed:" not in c else "" for c in cols1_fix]
cols = [c1 + "_" + c2 if c2 != "" else c1 for c1, c2 in zip(cols1_fix2, cols2)]
# cols
df.columns = cols
df = df.query("si_code == si_code")\
    .assign(categ_code = lambda df:df.categ_code.ffill(),
            categ_name = lambda df:df.categ_name.ffill())

cols_num_fix = df.columns[5:]
# cols_num_fix
for cf in cols_num_fix:
    # print(cf)
    df[[cf]] = df[[cf]].replace("-", "0").astype(float)
# Out:
# 外来
# 外来（加算）
# 入院
# 入院（加算）

# %%
df.head()
# Out:
#   categ_code categ_name    si_code             si_name point  totalcount  \
# 1       E000       透視診断  170000310                透視診断   110    235410.0
# 2       E001       写真診断  170000410        単純撮影（イ）の写真診断    85  69614130.0
# 3       E001       写真診断  170000510        単純撮影（ロ）の写真診断    43  30452100.0
# 4       E001       写真診断  170000610           特殊撮影の写真診断    96     36956.0
# 5       E001       写真診断  170000730  特殊撮影の写真診断（他方と同時併施）    48     79202.0
#
#    male_0～4歳  male_5～9歳  male_10～14歳  male_15～19歳  ...  female_45～49歳  \
# 1     2140.0     1054.0        821.0       1024.0  ...         4118.0
# 2   529103.0   658226.0     870925.0     753491.0  ...      1724509.0
# 3   252276.0   837457.0    2094628.0    1096408.0  ...       879669.0
# 4      172.0      654.0        676.0        694.0  ...          571.0
# 5      262.0      264.0        402.0        445.0  ...         1890.0
#
#    female_50～54歳  female_55～59歳  female_60～64歳  female_65～69歳  female_70～74歳  \
# 1         4781.0         5663.0         7274.0        12035.0        14431.0
# 2      1873394.0      2008672.0      2406966.0      3672854.0      4301147.0
# 3      1113681.0      1200135.0      1284591.0      1748730.0      1881211.0
# 4          701.0          830.0          917.0         1454.0         1584.0
# 5         1963.0         2400.0         3077.0         5005.0         5720.0
#
#    female_75～79歳  female_80～84歳  female_85～89歳  female_90歳以上
# 1        15864.0        14514.0        11607.0        9425.0
# 2      4987152.0      4662488.0      3434168.0     2122617.0
# 3      1956234.0      1561981.0       971829.0      487526.0
# 4         1897.0         1615.0          907.0         346.0
# 5         5778.0         4114.0         1898.0         680.0
#
# [5 rows x 44 columns]

# %%
def f2df_age(f, sheet_name):
    df = pd.read_excel(f_age, sheet_name=sheet_name, skiprows=2, dtype="object")
    cols1 = df.columns
    cols2 = df.loc[0,:]
    cols2 = [c if c ==c else "" for c in cols2]

    cols1_fix = ["categ_code", "categ_name", "si_code", "si_name", "point", "totalcount"] + list(cols1[6:])
    d_gen = {
        "男":"male",
        0:"male",
        "女":"female",
        1:"female",
    }
    cols1_fix2 = []
    for i, c in enumerate(cols1_fix):
        if "Unnamed:" in c and i <= 24:
            cols1_fix2.append("male")
        elif "Unnamed:" in c and 25 <= i:
            cols1_fix2.append("female")
        elif c == "男":
            cols1_fix2.append("male")
        elif c == "女":
            cols1_fix2.append("female")
        else:
            cols1_fix2.append(c)

    cols = [c1 + "_" + c2 if c2 != "" else c1 for c1, c2 in zip(cols1_fix2, cols2)]
    # cols
    df.columns = cols
    df = df.query("si_code == si_code")\
        .assign(categ_code = lambda df:df.categ_code.ffill(),
                categ_name = lambda df:df.categ_name.ffill())

    cols_num_fix = df.columns[5:]
    # cols_num_fix
    for cf in cols_num_fix:
        # print(cf)
        df[[cf]] = df[[cf]].replace("-", "0").astype(float)
        
    return df

# %%
f_age = "./000607901.xlsx"
# df.columns
df_age = f2df_age(f_age, sheet_name="外来")
# Out:
# 外来
# 外来（加算）
# 入院
# 入院（加算）

# %%
df_age.head()
# Out:
#   categ_code categ_name    si_code             si_name point  totalcount  \
# 1       E000       透視診断  170000310                透視診断   110    235410.0
# 2       E001       写真診断  170000410        単純撮影（イ）の写真診断    85  69614130.0
# 3       E001       写真診断  170000510        単純撮影（ロ）の写真診断    43  30452100.0
# 4       E001       写真診断  170000610           特殊撮影の写真診断    96     36956.0
# 5       E001       写真診断  170000730  特殊撮影の写真診断（他方と同時併施）    48     79202.0
#
#    male_0～4歳  male_5～9歳  male_10～14歳  male_15～19歳  ...  female_45～49歳  \
# 1     2140.0     1054.0        821.0       1024.0  ...         4118.0
# 2   529103.0   658226.0     870925.0     753491.0  ...      1724509.0
# 3   252276.0   837457.0    2094628.0    1096408.0  ...       879669.0
# 4      172.0      654.0        676.0        694.0  ...          571.0
# 5      262.0      264.0        402.0        445.0  ...         1890.0
#
#    female_50～54歳  female_55～59歳  female_60～64歳  female_65～69歳  female_70～74歳  \
# 1         4781.0         5663.0         7274.0        12035.0        14431.0
# 2      1873394.0      2008672.0      2406966.0      3672854.0      4301147.0
# 3      1113681.0      1200135.0      1284591.0      1748730.0      1881211.0
# 4          701.0          830.0          917.0         1454.0         1584.0
# 5         1963.0         2400.0         3077.0         5005.0         5720.0
#
#    female_75～79歳  female_80～84歳  female_85～89歳  female_90歳以上
# 1        15864.0        14514.0        11607.0        9425.0
# 2      4987152.0      4662488.0      3434168.0     2122617.0
# 3      1956234.0      1561981.0       971829.0      487526.0
# 4         1897.0         1615.0          907.0         346.0
# 5         5778.0         4114.0         1898.0         680.0
#
# [5 rows x 44 columns]

# %%
df_47.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 139 entries, 1 to 139
# Data columns (total 53 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   categ_code  139 non-null    object
#  1   categ_name  139 non-null    object
#  2   si_code     139 non-null    object
#  3   si_name     139 non-null    object
#  4   point       139 non-null    object
#  5   totalcount  139 non-null    float64
#  6   01_北海道      139 non-null    float64
#  7   02_青森県      139 non-null    float64
#  8   03_岩手県      139 non-null    float64
#  9   04_宮城県      139 non-null    float64
#  10  05_秋田県      139 non-null    float64
#  11  06_山形県      139 non-null    float64
#  12  07_福島県      139 non-null    float64
#  13  08_茨城県      139 non-null    float64
#  14  09_栃木県      139 non-null    float64
#  15  10_群馬県      139 non-null    float64
#  16  11_埼玉県      139 non-null    float64
#  17  12_千葉県      139 non-null    float64
#  18  13_東京都      139 non-null    float64
#  19  14_神奈川県     139 non-null    float64
#  20  15_新潟県      139 non-null    float64
#  21  16_富山県      139 non-null    float64
#  22  17_石川県      139 non-null    float64
#  23  18_福井県      139 non-null    float64
#  24  19_山梨県      139 non-null    float64
#  25  20_長野県      139 non-null    float64
#  26  21_岐阜県      139 non-null    float64
#  27  22_静岡県      139 non-null    float64
#  28  23_愛知県      139 non-null    float64
#  29  24_三重県      139 non-null    float64
#  30  25_滋賀県      139 non-null    float64
#  31  26_京都府      139 non-null    float64
#  32  27_大阪府      139 non-null    float64
#  33  28_兵庫県      139 non-null    float64
#  34  29_奈良県      139 non-null    float64
#  35  30_和歌山県     139 non-null    float64
#  36  31_鳥取県      139 non-null    float64
#  37  32_島根県      139 non-null    float64
#  38  33_岡山県      139 non-null    float64
#  39  34_広島県      139 non-null    float64
#  40  35_山口県      139 non-null    float64
#  41  36_徳島県      139 non-null    float64
#  42  37_香川県      139 non-null    float64
#  43  38_愛媛県      139 non-null    float64
#  44  39_高知県      139 non-null    float64
#  45  40_福岡県      139 non-null    float64
#  46  41_佐賀県      139 non-null    float64
#  47  42_長崎県      139 non-null    float64
#  48  43_熊本県      139 non-null    float64
#  49  44_大分県      139 non-null    float64
#  50  45_宮崎県      139 non-null    float64
#  51  46_鹿児島県     139 non-null    float64
#  52  47_沖縄県      139 non-null    float64
# dtypes: float64(48), object(5)
# memory usage: 58.6+ KB

# %%
df_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 139 entries, 1 to 139
# Data columns (total 44 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   categ_code     139 non-null    object
#  1   categ_name     139 non-null    object
#  2   si_code        139 non-null    object
#  3   si_name        139 non-null    object
#  4   point          139 non-null    object
#  5   totalcount     139 non-null    float64
#  6   male_0～4歳      139 non-null    float64
#  7   male_5～9歳      139 non-null    float64
#  8   male_10～14歳    139 non-null    float64
#  9   male_15～19歳    139 non-null    float64
#  10  male_20～24歳    139 non-null    float64
#  11  male_25～29歳    139 non-null    float64
#  12  male_30～34歳    139 non-null    float64
#  13  male_35～39歳    139 non-null    float64
#  14  male_40～44歳    139 non-null    float64
#  15  male_45～49歳    139 non-null    float64
#  16  male_50～54歳    139 non-null    float64
#  17  male_55～59歳    139 non-null    float64
#  18  male_60～64歳    139 non-null    float64
#  19  male_65～69歳    139 non-null    float64
#  20  male_70～74歳    139 non-null    float64
#  21  male_75～79歳    139 non-null    float64
#  22  male_80～84歳    139 non-null    float64
#  23  male_85～89歳    139 non-null    float64
#  24  male_90歳以上     139 non-null    float64
#  25  female_0～4歳    139 non-null    float64
#  26  female_5～9歳    139 non-null    float64
#  27  female_10～14歳  139 non-null    float64
#  28  female_15～19歳  139 non-null    float64
#  29  female_20～24歳  139 non-null    float64
#  30  female_25～29歳  139 non-null    float64
#  31  female_30～34歳  139 non-null    float64
#  32  female_35～39歳  139 non-null    float64
#  33  female_40～44歳  139 non-null    float64
#  34  female_45～49歳  139 non-null    float64
#  35  female_50～54歳  139 non-null    float64
#  36  female_55～59歳  139 non-null    float64
#  37  female_60～64歳  139 non-null    float64
#  38  female_65～69歳  139 non-null    float64
#  39  female_70～74歳  139 non-null    float64
#  40  female_75～79歳  139 non-null    float64
#  41  female_80～84歳  139 non-null    float64
#  42  female_85～89歳  139 non-null    float64
#  43  female_90歳以上   139 non-null    float64
# dtypes: float64(39), object(5)
# memory usage: 48.9+ KB
